# %%
import pickle
# %matplotlib inline

# %%
cd ~/implement/wetmsm/bphc/abspos/
# Out:
# /home/harrigan/implement/wetmsm/bphc/abspos

# %%
try:
    seqs
except NameError:
    with open('abspos.pickl', 'rb') as f:
        seqs = pickle.load(f)

# %%
from mixtape.tica import tICA

# %%
tica = tICA(n_components=10, lag_time=10, weighted_transform=True)

# %%
len(seqs)
seqs[0].shape
# Out:
# (1001, 876)

# %%
tica.fit(seqs)
# Out:
# tICA(gamma=0.05, lag_time=10, n_components=10, weighted_transform=True)

# %%
# Force to eigensolve
tica.timescales_.shape
# Out:
# (10,)

# %%
plt.subplots(figsize=(3,5))
plt.hlines(tica.timescales_, 0, 1, 'b')

# %%
if tica is not None and tica.components_ is not None:
    with open('abspos_tica.pickl', 'wb') as f:
        pickle.dump(tica, f)

# %% [markdown]
# # Transform

# %%
tseq = tica.transform(seqs)

# %%
txy = np.vstack(tseq)
print(txy.shape)
# Out:
# (87704, 10)

# %%
import scipy.stats

# %%
kde = scipy.stats.gaussian_kde(txy[:,:2].T)

# %%
npoints = 100
xlin = np.linspace(np.min(txy[:,0]), np.max(txy[:,0]), npoints)
ylin = np.linspace(np.min(txy[:,1]), np.max(txy[:,1]), npoints)
xx, yy = np.meshgrid(xlin, ylin)
pos = np.vstack([xx.ravel(), yy.ravel()])
pos.shape
zz = kde.evaluate(pos)
zz = np.reshape(zz.T, xx.shape)

# %%
plt.subplots(figsize=(8,5))
plt.contourf(xx, yy, zz, 200)
plt.xlabel('|Pos| tIC 1')
plt.ylabel('|Pos| tIC 2')
plt.savefig('abspos_tica_kde.png')

# %%
if tseq is not None:
    with open('abspos_tica_transform.pickl', 'wb') as f:
        pickle.dump(tseq, f)
