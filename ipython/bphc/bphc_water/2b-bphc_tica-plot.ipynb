# %%
# %matplotlib inline

# %%
import pickle

# %%
cd ~/implement/wetmsm/bphc/hoh
# Out:
# /home/harrigan/implement/wetmsm/bphc/hoh

# %%
with open('fp_ic.pickl', 'rb') as f:
    ticax = pickle.load(f)
txy = np.concatenate(ticax)

# %% [markdown]
# # Plots

# %%
plt.subplots(figsize=(8,5))
_ = plt.hist2d(txy[:,0], txy[:,1], bins=80, cmin=5, cmap=plt.get_cmap('terrain'))
plt.xlabel('Solvent tIC 1')
plt.ylabel('Solvent tIC 2')
plt.savefig('figs-2-tica/hist.pdf')

# %%
import pandas as pd

# %%
txydf = pd.DataFrame(ticax[0])

# %%
plt.subplots(figsize=(8,5))
_ = plt.hist2d(txy[:,0], txy[:,1], bins=80, cmin=1, cmap=plt.get_cmap('terrain'))

for tx in ticax[::10]:
    txydf = pd.DataFrame(tx)
    ma = pd.rolling_mean(txydf, 80).dropna()
    plt.plot(ma[::1][0], ma[::1][1], 'r-', zorder=11, linewidth=2, label='Smoothed')
plt.savefig('figs-2-tica/hist_with-paths.pdf')
