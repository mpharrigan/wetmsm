# %%
# %matplotlib inline

# %%
cd ~/implement/wetmsm/ala/dihed
# Out:
# /home/harrigan/implement/wetmsm/ala/dihed

# %%
import pickle

# %%
with open('dihed.pickl', 'rb') as f:
    tseq = pickle.load(f)

# %%
# Only do 2 tics
tseqt = [ts[:,:2] for ts in tseq]

# %%
n_datapoint = int(np.sum([len(fp2d) for fp2d in tseq]))
n_cluster = int(np.ceil(np.sqrt(n_datapoint/2)))
print("{} datapoints. Using {} clusters".format(n_datapoint, n_cluster))
# Out:
# 350000 datapoints. Using 419 clusters

# %%
from mixtape.cluster import KMeans
from mixtape.markovstatemodel import MarkovStateModel

# %%
kmeans = KMeans(n_clusters=n_cluster, n_jobs=6)

# %%
kmeans.fit(tseqt)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=419, n_init=10,
#     n_jobs=6, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %%
for fp in tseq:
    plt.scatter(fp[:,0], fp[:,1], s=1, linewidth=0, alpha=0.2)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='r')

# %%
sym = 'mle'
lagtimes = list()
timescales = list()
for lt in range(1, 30, 2):
    print(lt)
    msm = MarkovStateModel(lag_time=lt, n_timescales=20, reversible_type=sym)
    msm.fit(kmeans.labels_)
    timescales.append(msm.timescales_)
    lagtimes.append([lt] * msm.n_timescales)
# Out:
# 1
# 12:45:13 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 3
# 5
# 7
# 12:45:26 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 9
# 12:45:30 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 11
# 12:45:36 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 13
# 12:45:41 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 15
# 17
# 12:45:50 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 19
# 21
# 12:46:00 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 23
# 12:46:05 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 25
# 12:46:10 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 27
# 12:46:16 - Abnormal termination of BFGS likelihood maximization.  Error code 2
# 29
# 12:46:21 - Abnormal termination of BFGS likelihood maximization.  Error code 2

# %%
timescales = np.array(timescales).flatten()
lagtimes = np.array(lagtimes).flatten()
print(timescales.shape, lagtimes.shape)
# Out:
# (300,) (300,)

# %%
plt.scatter(lagtimes, timescales)
plt.yscale('log')

# %%
msm = MarkovStateModel(lag_time=5, n_timescales=20, reversible_type=sym)
msm.fit(kmeans.labels_)
# Out:
# MarkovStateModel(ergodic_trim=True, lag_time=5, n_states=419, n_timescales=20,
#          prior_counts=0, reversible_type='mle')

# %%
np.all([v >=0 for v in msm.mapping_.values()])
# Out:
# True

# %% [markdown]
# # Spectra

# %%
plt.subplots(figsize=(3,5))
plt.hlines(msm.timescales_, 0, 1, 'b')
plt.xticks([])
plt.yscale('log')
plt.title('Dihed MSM Timescales')
plt.suptitle('lagtime = 5')
plt.savefig('dihed_msm_timescales_{}.png'.format(sym))

# %% [markdown]
# ## Eigenvectors

# %%
ev = msm.eigenvectors_
ts = np.append([np.inf], msm.timescales_)

# %%
def plot_eigen(eigeni):
    plt.subplots(figsize=(8,5))
    e1 = ev[:,eigeni] / np.sqrt(np.dot(ev[:,eigeni], ev[:,eigeni]))
    pos_ind = np.where(e1>=0)[0]
    neg_ind = np.where(e1<0)[0]
    print(len(pos_ind), len(neg_ind))
    
    for fp in tseq:
        plt.scatter(fp[:,0], fp[:,1], s=1, linewidth=0, alpha=0.2, c='g')
    plt.scatter(kmeans.cluster_centers_[pos_ind,0], kmeans.cluster_centers_[pos_ind,1],
                c='r',  linewidth=1.5, s=1000*e1[pos_ind], alpha=0.8, zorder=10)
    plt.scatter(kmeans.cluster_centers_[neg_ind,0], kmeans.cluster_centers_[neg_ind,1],
                c='b',  linewidth=1.5, s=-1000*e1[neg_ind], alpha=0.8, zorder=10)
    plt.title('Eigenvector {}, Timescale {:.1f}'.format(eigeni, ts[eigeni]))
    plt.xlabel('Phi')
    plt.ylabel('Psi')
    plt.gca().set_axis_bgcolor('#F9F9F9')
    plt.savefig("dihedmsm_eigenv-{}-{}".format(eigeni, sym))

# %%
plot_eigen(0)
# Out:
# 419 0

# %%
plot_eigen(1)
# Out:
# 386 33

# %%
plot_eigen(2)
# Out:
# 194 225

# %%
plot_eigen(3)
# Out:
# 234 185

# %%
plot_eigen(4)
# Out:
# 198 221

# %% [markdown]
# # Do PCCA

# %%
from msmbuilder.lumping import PCCAPlus

# %%
pcca = PCCAPlus(msm.transmat_, 5)
# Out:
# 12:49:10 - Minimizing PCCA+ objective function.
# 12:49:10 - Initial value of objective function: f = -3.936714
# Warning: Maximum number of iterations exceeded.
# Optimization terminated successfully.
#          Current function value: -3.937968
#          Iterations: 33
#          Function evaluations: 188
# 12:49:11 - Final value: f = -3.937968
# /home/harrigan/opt/Python-3.4/lib/python3.4/site-packages/numpy/lib/utils.py:134: DeprecationWarning: `anneal` is deprecated!
# Deprecated in scipy 0.14.0, use basinhopping instead
#   warnings.warn(depdoc, DeprecationWarning)

# %%
plt.subplots(figsize=(8,5))
for fp in tseq:
        plt.scatter(fp[:,0], fp[:,1], s=1, linewidth=0, alpha=0.2, c='g')
        
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
                c=pcca.microstate_mapping,  linewidth=1.5, s=30000*pcca.populations,
                alpha=0.9, zorder=10, cmap=plt.cm.get_cmap('Spectral'))

plt.title('PCCA+')
plt.xlabel('Phi')
plt.ylabel('Psi')
plt.gca().set_axis_bgcolor('#F9F9F9')
#plt.savefig("watermsm_eigenv-{}-{}".format(sym, eigeni))

# %%
plt.subplots(figsize=(10,6))

for fp in tseq:
    plt.scatter(fp[:,0], fp[:,1], s=1, linewidth=0, alpha=0.2, c='g')

for i, (x, y) in enumerate(kmeans.cluster_centers_):
    plt.annotate(xy=(x,y), s='{}'.format(i), size=8)

# %% [markdown]
# # Combine

# %%
ls ..
# Out:
# dihed/          fp2d_deleted.pickl  fp_ic.pickl         water_fns.pickl            water_tic_kde.png
# fp2d_all.pickl  fp3dn_all.pickl     ic_estimator.pickl  water_tica_timescales.png

# %%
with open('../fp_ic.pickl', 'rb') as f:
    wseq = pickle.load(f)

# %%
for fp in wseq:
    plt.scatter(fp[:,0], fp[:,1], alpha=0.2, linewidth=0, s=2)

# %%
from mixtape.cluster import MiniBatchKMeans

# %%
wkmeans = MiniBatchKMeans(n_clusters=6)

# %%
wkmeans.fit([fp[:,0:2] for fp in wseq])
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=100, max_no_improvement=10, n_clusters=6,
#         n_init=3, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)

# %%
plt.subplots(figsize=(8,5))
for fp, labs in zip(wseq, wkmeans.labels_):
    plt.scatter(fp[:,0], fp[:,1], alpha=0.2, linewidth=0, s=1, c=labs)
plt.xlabel('Water tIC 1'); plt.ylabel('Water tIC 2')
plt.savefig('ala_water_tic_cluster_hs.png')

# %%
plt.subplots(figsize=(8,5))
for fp, labs in zip(tseq, wkmeans.labels_):
    plt.scatter(fp[:,0], fp[:,1], alpha=0.2, linewidth=0, s=1, c=labs)
plt.xlabel('Phi'); plt.ylabel('Psi')
plt.savefig('ala_watertic_on_dihed_tinsel_hs.png')

# %% [markdown]
# # PCA

# %%
with open('../pca_transform.pickl', 'rb') as f:
    pxy = pickle.load(f)

# %%
plt.scatter(pxy[:,0], pxy[:,1], alpha=0.1, s=1, linewidth=0)

# %%
pkmeans = MiniBatchKMeans(n_clusters=5)

# %%
formeans = np.vstack((pxy[:,0]/20, pxy[:,1])).T
print(formeans.shape)
# Out:
# (350000, 2)

# %%
pkmeans.fit([formeans])
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=100, max_no_improvement=10, n_clusters=5,
#         n_init=3, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)

# %%
plt.scatter(pxy[:,0], pxy[:,1], alpha=0.2, s=1, linewidth=0, c=pkmeans.labels_)

# %%
txy = np.vstack([fp[:,0:2] for fp in tseq])
print(txy.shape)
# Out:
# (350000, 2)

# %%
plt.subplots(figsize=(8,5))
plt.scatter(txy[:,0], txy[:,1], alpha=0.2, linewidth=0, s=1, c=pkmeans.labels_)
plt.xlabel('Phi'); plt.ylabel('Psi')
