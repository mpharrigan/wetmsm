# %%
# %matplotlib inline

# %%
cd ~/biox/implement/water/ala-mine2
# Out:
# /home/harrigan/mnt/biox/biox3/home/harrigan/implement/water/ala-mine2

# %% [markdown]
# ## Load in fingerprint

# %%
import tables

# %%
ls trajs/
# Out:
# traj-1.dcd@                    traj-2.dcd.o.5x3a.count.h5     traj-4.dcd.o.5x2a.assign.h5    traj-6.dcd.h12.5x3a.count.h5
# traj-1.dcd.h12.5x2a.assign.h5  traj-2.dcd.o.6x1a.assign.h5    traj-4.dcd.o.5x2a.count.h5     traj-6.dcd.h12.6x1a.assign.h5
# traj-1.dcd.h12.5x2a.count.h5   traj-2.dcd.o.6x1a.count.h5     traj-4.dcd.o.5x3a.assign.h5    traj-6.dcd.h12.6x1a.count.h5
# traj-1.dcd.h12.5x3a.assign.h5  traj-3.dcd@                    traj-4.dcd.o.5x3a.count.h5     traj-6.dcd.o.5x2a.assign.h5
# traj-1.dcd.h12.5x3a.count.h5   traj-3.dcd.h12.5x2a.assign.h5  traj-4.dcd.o.6x1a.assign.h5    traj-6.dcd.o.5x2a.count.h5
# traj-1.dcd.h12.6x1a.assign.h5  traj-3.dcd.h12.5x2a.count.h5   traj-4.dcd.o.6x1a.count.h5     traj-6.dcd.o.5x3a.assign.h5
# traj-1.dcd.h12.6x1a.count.h5   traj-3.dcd.h12.5x3a.assign.h5  traj-5.dcd@                    traj-6.dcd.o.5x3a.count.h5
# traj-1.dcd.o.5x2a.assign.h5    traj-3.dcd.h12.5x3a.count.h5   traj-5.dcd.h12.5x2a.assign.h5  traj-6.dcd.o.6x1a.assign.h5
# traj-1.dcd.o.5x2a.count.h5     traj-3.dcd.h12.6x1a.assign.h5  traj-5.dcd.h12.5x2a.count.h5   traj-6.dcd.o.6x1a.count.h5
# traj-1.dcd.o.5x3a.assign.h5    traj-3.dcd.h12.6x1a.count.h5   traj-5.dcd.h12.5x3a.assign.h5  traj-7.dcd@
# traj-1.dcd.o.5x3a.count.h5     traj-3.dcd.o.5x2a.assign.h5    traj-5.dcd.h12.5x3a.count.h5   traj-7.dcd.h12.5x2a.assign.h5
# traj-1.dcd.o.6x1a.assign.h5    traj-3.dcd.o.5x2a.count.h5     traj-5.dcd.h12.6x1a.assign.h5  traj-7.dcd.h12.5x2a.count.h5
# traj-1.dcd.o.6x1a.count.h5     traj-3.dcd.o.5x3a.assign.h5    traj-5.dcd.h12.6x1a.count.h5   traj-7.dcd.h12.5x3a.assign.h5
# traj-2.dcd@                    traj-3.dcd.o.5x3a.count.h5     traj-5.dcd.o.5x2a.assign.h5    traj-7.dcd.h12.5x3a.count.h5
# traj-2.dcd.h12.5x2a.assign.h5  traj-3.dcd.o.6x1a.assign.h5    traj-5.dcd.o.5x2a.count.h5     traj-7.dcd.h12.6x1a.assign.h5
# traj-2.dcd.h12.5x2a.count.h5   traj-3.dcd.o.6x1a.count.h5     traj-5.dcd.o.5x3a.assign.h5    traj-7.dcd.h12.6x1a.count.h5
# traj-2.dcd.h12.5x3a.assign.h5  traj-4.dcd@                    traj-5.dcd.o.5x3a.count.h5     traj-7.dcd.o.5x2a.assign.h5
# traj-2.dcd.h12.5x3a.count.h5   traj-4.dcd.h12.5x2a.assign.h5  traj-5.dcd.o.6x1a.assign.h5    traj-7.dcd.o.5x2a.count.h5
# traj-2.dcd.h12.6x1a.assign.h5  traj-4.dcd.h12.5x2a.count.h5   traj-5.dcd.o.6x1a.count.h5     traj-7.dcd.o.5x3a.assign.h5
# traj-2.dcd.h12.6x1a.count.h5   traj-4.dcd.h12.5x3a.assign.h5  traj-6.dcd@                    traj-7.dcd.o.5x3a.count.h5
# traj-2.dcd.o.5x2a.assign.h5    traj-4.dcd.h12.5x3a.count.h5   traj-6.dcd.h12.5x2a.assign.h5  traj-7.dcd.o.6x1a.assign.h5
# traj-2.dcd.o.5x2a.count.h5     traj-4.dcd.h12.6x1a.assign.h5  traj-6.dcd.h12.5x2a.count.h5   traj-7.dcd.o.6x1a.count.h5
# traj-2.dcd.o.5x3a.assign.h5    traj-4.dcd.h12.6x1a.count.h5   traj-6.dcd.h12.5x3a.assign.h5

# %%
n_shells = 6
shell_w = 0.1
code = "{:d}x{:d}a".format(n_shells, int(10*shell_w))

seqs = []
fns = []
for i in range(1,8):
    fno = 'trajs/traj-{}.dcd.o.{}.count.h5'.format(i, code)
    fnh12 = 'trajs/traj-{}.dcd.h12.{}.count.h5'.format(i, code)
    
    #fnoa = 'trajs/traj-{}.dcd.o.{}.assign.h5'.format(i, code)
    #fnh12a = 'trajs/traj-{}.dcd.h12.{}.assign.h5'.format(i, code)
    
    fo = tables.open_file(fno)
    fh12 = tables.open_file(fnh12)
    
    #foa = tables.open_file(fnoa)
    #fh12a = tables.open_file(fnh12a)
    
    fp3d_tmp = np.hstack((fo.root.shell_counts, fh12.root.shell_counts))
    print(fp3d_tmp.shape)
    
    seqs.append(fp3d_tmp)
    fns.append(fno)
# Out:
# (50000, 18, 6)
# (50000, 18, 6)
# (50000, 18, 6)
# (50000, 18, 6)
# (50000, 18, 6)
# (50000, 18, 6)
# (50000, 18, 6)

# %%
from wetmsm.analysis import SolventShellsAnalysis

# %%
sa = SolventShellsAnalysis(seqs, shell_w)

# %%
fp2d = sa.seqs2d[np.random.randint(len(sa.seqs2d))]
for i in np.random.randint(0, fp2d.shape[1], 4):
    plt.plot(fp2d[::100, i], '.-', label="Feature {}".format(i))
plt.xlabel('Time'); plt.ylabel('Shells FP');
plt.legend(loc='best')

# %%
cd ~/implement/wetmsm/ala-2/
# Out:
# /home/harrigan/implement/wetmsm/ala-2

# %%
import pickle
with open('1-solvent_analysis.pickl', 'wb') as f:
    pickle.dump(sa, f)
