# %%
# %matplotlib inline

# %%
import pickle
import glob
import tables

# %%
cd ~/biox/implement/water/ala-fine/
# Out:
# /home/harrigan/mnt/biox/biox3/home/harrigan/implement/water/ala-fine

# %%
n_shells = 5
shell_w = 0.2

seqs = []
fns = []
for i in range(1,8):
    fno = 'trajs/traj-{}.dcd.o.count.h5'.format(i)
    fnh12 = 'trajs/traj-{}.dcd.h12.count.h5'.format(i)
    
    fo = tables.open_file(fno)
    fh12 = tables.open_file(fnh12)
    
    fp3d_tmp = np.hstack((fo.root.shell_counts, fh12.root.shell_counts))
    print(fp3d_tmp.shape)
    
    seqs.append(fp3d_tmp)
    fns.append(fno)
# Out:
# (50000, 18, 5)
# (50000, 18, 5)
# (50000, 18, 5)
# (50000, 18, 5)
# (50000, 18, 5)
# (50000, 18, 5)
# (50000, 18, 5)

# %%
from wetmsm.analysis import SolventShellsAnalysis
sa = SolventShellsAnalysis(seqs, shell_w)

# %%
fp2d = sa.seqs2d[np.random.randint(len(sa.seqs2d))]
for i in np.random.randint(0, fp2d.shape[1], 4):
    plt.plot(fp2d[::100, i], '.-', label="Feature {}".format(i))
plt.xlabel('Time'); plt.ylabel('Shells FP');
plt.legend(loc='best')

# %%
cd ~/implement/wetmsm/ala-fine
# Out:
# /home/harrigan/implement/wetmsm/ala-fine

# %%
with open('1-solvent_analysis.pickl', 'wb') as f:
    pickle.dump(sa, f)
