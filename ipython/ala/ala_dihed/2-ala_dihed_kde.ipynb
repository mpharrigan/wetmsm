# %%
import pickle
# %matplotlib inline

# %%
cd ~/implement/wetmsm/ala/dihed/
# Out:
# /home/harrigan/implement/wetmsm/ala/dihed

# %%
try:
    seqs
except NameError:
    with open('dihed.pickl', 'rb') as f:
        seqs = pickle.load(f)

# %%
for fp in seqs:
    plt.scatter(fp[:,0], fp[:,1], color='g', alpha=0.2, linewidth=0, s=1)

# %% [markdown]
# # KDE

# %%
txy = np.vstack(seqs)
print(txy.shape)
# Out:
# (350000, 2)

# %%
import scipy.stats

# %%
kde = scipy.stats.gaussian_kde(txy.T)

# %%
npoints = 100
xlin = np.linspace(np.min(txy[:,0]), np.max(txy[:,0]), npoints)
ylin = np.linspace(np.min(txy[:,1]), np.max(txy[:,1]), npoints)
xx, yy = np.meshgrid(xlin, ylin)
pos = np.vstack([xx.ravel(), yy.ravel()])
pos.shape
zz = kde.evaluate(pos)
zz = np.reshape(zz.T, xx.shape)

# %%
plt.subplots(figsize=(8,5))
plt.contourf(xx,yy,zz, 200)
plt.xlabel('Phi')
plt.ylabel('Psi')
plt.savefig('phipsi.png')
