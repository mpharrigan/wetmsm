# %%
# %matplotlib inline

# %%
import pickle
from wetmsm.analysis import SolventShellsAnalysis

# %%
cd ~/implement/wetmsm/ala-fine
# Out:
# /home/harrigan/implement/wetmsm/ala-fine

# %%
n_shells = 5
shell_w = 0.2

# %%
with open('2-tica.pickl', 'rb') as f:
    sa = pickle.load(f)

# %% [markdown]
# # Auto

# %%
plt.scatter(range(len(sa.pca.components_[1])), sa.pca.components_[1])

# %%
print(np.where(sa.pca.components_[1] > 0.4))
print(np.where(sa.pca.components_[1] < -0.4))
# Out:
# (array([68]),)
# (array([43]),)

# %%
swq = sa.seqs2d[1]

# %%
swq1 = swq[:,70] - np.mean(swq[:,70])
plt.plot(swq1)

# %%
swq1.shape
# Out:
# (50000,)

# %%
ac = [np.sum(swq1[:len(swq1)-t] * swq1[t:]) for t in range(0, 400)]

# %%
plt.plot(ac)

# %% [markdown]
# # Atomy

# %%
pc1 =
