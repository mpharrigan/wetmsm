# %%
# %matplotlib inline

# %%
import pickle
from mixtape.tica import tICA

# %%
cd ~/implement/wetmsm/gpcr/3p0g/abspos
# Out:
# /home/harrigan/implement/wetmsm/gpcr/3p0g/abspos

# %%
with open('1-seqs.pickl', 'rb') as f:
    seqs = pickle.load(f)

# %% [markdown]
# # Do tICA

# %%
tica = tICA(n_components=10, weighted_transform=True)

# %%
tica.fit(seqs)
# Out:
# tICA(gamma=0.05, lag_time=1, n_components=10, weighted_transform=True)

# %%
tseqs = tica.transform(seqs)
txy = np.concatenate(tseqs)

# %% [markdown]
# # Visualize

# %%
plt.scatter(txy[:,0], txy[:,1], linewidth=0, s=1, alpha=0.1)

# %%
plt.subplots(figsize=(3,5))
plt.hlines(tica.timescales_, 0, 1, 'b')

# %% [markdown]
# # Save

# %%
with open('2-tica.pickl', 'wb') as f:
    pickle.dump(tica, f)
with open('3-ticax.pickl', 'wb') as f:
    pickle.dump(tseqs, f)

# %%
ls -rtlh
# Out:
# total 878M
# -rw-rw-r-- 1 harrigan harrigan 841M Jul 31 13:02 1-seqs.pickl
# -rw-rw-r-- 1 harrigan harrigan 574K Jul 31 13:02 1-seqs.fns.pickl
# -rw-rw-r-- 1 harrigan harrigan  16M Jul 31 13:13 2-tica.pickl
# -rw-rw-r-- 1 harrigan harrigan  21M Jul 31 13:13 3-ticax.pickl
