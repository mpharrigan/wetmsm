# %%
# %matplotlib inline

# %%
import pickle
from mixtape.tica import tICA

# %% [markdown]
# # Use sub-fit tica's
# Fitting tICA on the combined data leads to unconnected groups. See how good we can get by using each individual tica transform on all data

# %%
cd ~/implement/wetmsm/gpcr/
# Out:
# /home/harrigan/implement/wetmsm/gpcr

# %%
with open('2rh1/hoh/2-hoh-tica.pickl', 'rb') as f:
    tica1 = pickle.load(f)
with open('3p0g/hoh/2-hoh-tica.pickl', 'rb') as f:
    tica2 = pickle.load(f)

# %% [markdown]
# ## Load data

# %%
cd together/hoh
# Out:
# /home/harrigan/implement/wetmsm/gpcr/together/hoh

# %%
with open('1-seqs2d.pickl', 'rb') as f:
    seqs = pickle.load(f)

# %%
for s in seqs:
    assert s.shape[1] == 1100

# %% [markdown]
# # Apply transform

# %%
tseqs1 = tica1.transform(seqs)

# %%
tseqs2 = tica2.transform(seqs)

# %%
txy1 = np.concatenate(tseqs1)
txy2 = np.concatenate(tseqs2)

# %% [markdown]
# # Visualize

# %%
col = np.zeros(len(txy1))
col[len(txy1)//2:] = 1

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8*2, 5))
ax1.scatter(txy1[:,0], txy1[:,1], linewidth=0, s=1, alpha=0.1, c=col)
ax2.scatter(txy2[:,0], txy2[:,1], linewidth=0, s=1, alpha=0.1, c=col)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8*2, 5))
_ = ax1.hist2d(txy1[:,0], txy1[:,1], bins=70, cmin=10)
_ = ax2.hist2d(txy2[:,0], txy2[:,1], bins=70, cmin=10)

# %% [markdown]
# # Compare

# %%
plt.subplots(figsize=(8,5))
plt.scatter(txy1[:,0], txy2[:,0], linewidth=0, s=1, alpha=0.1, c=col)
