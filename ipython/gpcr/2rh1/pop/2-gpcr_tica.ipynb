# %%
# %matplotlib inline

# %%
import pickle

# %%
cd ~/implement/wetmsm/gpcr/
# Out:
# /home/harrigan/implement/wetmsm/gpcr

# %% [markdown]
# # Tica Plots

# %%
with open('2-pop-tica.pickl', 'rb') as f:
    tica = pickle.load(f)
with open('3-pop-ticax.pickl', 'rb') as f:
    ticax = pickle.load(f)

# %%
print(len(ticax),ticax.__class__)
# Out:
# 9982 <class 'list'>

# %%
txy = np.concatenate(ticax)

# %%
plt.scatter(txy[:,0], txy[:,1], linewidth=0, s=1, alpha=0.1)

# %%
from matplotlib.colors import NoNorm, Normalize, LogNorm

# %%
cmap = plt.get_cmap('jet')
counts, xedges, yedges, _ = plt.hist2d(txy[:,0], txy[:,1], bins=100, norm=LogNorm(), cmap=cmap)
#plt.plot(ticax[1848][:,0], ticax[1848][:,1], 'ro-')

# %%
plt.subplots(figsize=(3,5))
plt.hlines(tica.timescales_, 0, 1, 'b')
